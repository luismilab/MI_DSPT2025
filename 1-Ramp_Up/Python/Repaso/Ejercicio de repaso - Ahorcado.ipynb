# %% [markdown]
# ## Juego del Ahorcado
# Desarrolla el juego del ahorcado en python. En cada turno irá mostrando por pantalla ```_ _ _ _ _``` las rayas bajas correspondientes al número de letras que tiene la palabra a adivinar. El usuario deberá insertar una letra y, si esa letra existe, se mostrará o mostrarán las letras acertadas ```S _ S _ _``` en sus posiciones correspondientes.
#
# Si falla, se mostrará el número de errores que lleva y, si lleva x errores, entonces se mostrará "Fin del juego".

# %% [markdown]
# 1. Inicializa el juego: declara una palabra a adivinar y muestra por pantalla la palabra oculta.

# %% [markdown]
# ```python
# _ _ _ _ _ _ _ _
# ```

# %%
import random

# Función para obtener una palabra aleatoria
def obtener_palabra_aleatoria():
    palabras = ['python', 'programacion', 'desarrollo', 'computadora', 'teclado']
    return random.choice(palabras)

# Función para mostrar el tablero del ahorcado
def mostrar_tablero(intentos):
    figura = [
        '''
          +---+
          |   |
              |
              |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
              |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
          |   |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
         /|   |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
         /|\\  |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
         /|\\  |
         /    |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
         /|\\  |
         / \\  |
              |
        ========'''
    ]
    print(figura[intentos])

# Función para jugar al ahorcado
def jugar_ahorcado():
    palabra = obtener_palabra_aleatoria()
    letras_adivinadas = []
    intentos = 0

    while True:
        mostrar_tablero(intentos)

        estado = ''
        for letra in palabra:
            if letra in letras_adivinadas:
                estado += letra + ' '
            else:
                estado += '_ '
        print(estado)

        if estado.replace(" ", "") == palabra:
            print('¡Felicidades! ¡Has adivinado la palabra correctamente!')
            break

        if intentos == 6:
            print('¡Oh no! Te has quedado sin intentos. La palabra era:', palabra)
            break

        letra = input('Ingresa una letra: ').lower()

        if len(letra) != 1 or not letra.isalpha():
            print('Por favor, ingresa una sola letra válida.')
            continue

        if letra in letras_adivinadas:
            print('Ya has ingresado esa letra antes. ¡Intenta con otra!')
            continue

        letras_adivinadas.append(letra)

        if letra not in palabra:
            intentos += 1
            print('La letra', letra, 'no está en la palabra. ¡Te quedan', 6 - intentos, 'intentos!')

# Iniciar el juego
jugar_ahorcado()

# %% [markdown]
# 2. Funcionamiento turnos: mediante un bucle genera el sistema de turnos donde el usuario introduce una letra y le va mostrando su progreso y sus vidas.

# %%
import random

# Función para obtener una palabra aleatoria
def obtener_palabra_aleatoria():
    palabras = ['python', 'programacion', 'desarrollo', 'computadora', 'teclado']
    return random.choice(palabras)

# %%
# Función para mostrar el tablero del ahorcado
def mostrar_tablero(intentos):
    figura = [
        '''
          +---+
          |   |
              |
              |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
              |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
          |   |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
         /|   |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
         /|\\  |
              |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
         /|\\  |
         /    |
              |
        ========''',
        '''
          +---+
          |   |
          O   |
         /|\\  |
         / \\  |
              |
        ========'''
    ]
    print(figura[intentos])

# %%
# Función para jugar al ahorcado
def jugar_ahorcado():
    palabra = obtener_palabra_aleatoria()
    letras_adivinadas = []
    intentos = 0

    while True:
        mostrar_tablero(intentos)

        estado = ''
        for letra in palabra:
            if letra in letras_adivinadas:
                estado += letra + ' '
            else:
                estado += '_ '
        print(estado)

        if estado.replace(" ", "") == palabra:
            print('¡Felicidades! ¡Has adivinado la palabra correctamente!')
            break

        if intentos == 6:
            print('¡Oh no! Te has quedado sin intentos. La palabra era:', palabra)
            break

        letra = input('Ingresa una letra: ').lower()

        if len(letra) != 1 or not letra.isalpha():
            print('Por favor, ingresa una sola letra válida.')
            continue

        if letra in letras_adivinadas:
            print('Ya has ingresado esa letra antes. ¡Intenta con otra!')
            continue

        letras_adivinadas.append(letra)

        if letra not in palabra:
            intentos += 1
            print('La letra', letra, 'no está en la palabra. ¡Te quedan', 6 - intentos, 'intentos!')

# %%
# Iniciar el juego
jugar_ahorcado()
# Out:
#           +---+
#           |   |
#               |
#               |
#               |
#               |
#         ========
# _ _ _ _ _ _ _ _ _ _ _ _
# La letra j no está en la palabra. ¡Te quedan 5 intentos!
#
#           +---+
#           |   |
#           O   |
#               |
#               |
#               |
#         ========
# _ _ _ _ _ _ _ _ _ _ _ _
#
#           +---+
#           |   |
#           O   |
#               |
#               |
#               |
#         ========
# p _ _ _ _ _ _ _ _ _ _ _
# La letra h no está en la palabra. ¡Te quedan 4 intentos!
#
#           +---+
#           |   |
#           O   |
#           |   |
#               |
#               |
#         ========
# p _ _ _ _ _ _ _ _ _ _ _
# La letra y no está en la palabra. ¡Te quedan 3 intentos!
#
#           +---+
#           |   |
#           O   |
#          /|   |
#               |
#               |
#         ========
# p _ _ _ _ _ _ _ _ _ _ _
# La letra t no está en la palabra. ¡Te quedan 2 intentos!
#
#           +---+
#           |   |
#           O   |
#          /|\  |
#               |
#               |
#         ========
# p _ _ _ _ _ _ _ _ _ _ _
# Ya has ingresado esa letra antes. ¡Intenta con otra!
#
#           +---+
#           |   |
#           O   |
#          /|\  |
#               |
#               |
#         ========
# p _ _ _ _ _ _ _ _ _ _ _
#
#           +---+
#           |   |
#           O   |
#          /|\  |
#               |
#               |
#         ========
# p _ o _ _ _ _ _ _ _ o _
#
#           +---+
#           |   |
#           O   |
#          /|\  |
#               |
#               |
#         ========
# p _ o _ _ _ _ _ _ _ o n
#
#           +---+
#           |   |
#           O   |
#          /|\  |
#               |
#               |
#         ========
# p _ o g _ _ _ _ _ _ o n
# La letra x no está en la palabra. ¡Te quedan 1 intentos!
#
#           +---+
#           |   |
#           O   |
#          /|\  |
#          /    |
#               |
#         ========
# p _ o g _ _ _ _ _ _ o n
# La letra b no está en la palabra. ¡Te quedan 0 intentos!
#
#           +---+
#           |   |
#           O   |
#          /|\  |
#          / \  |
#               |
#         ========
# p _ o g _ _ _ _ _ _ o n
# ¡Oh no! Te has quedado sin intentos. La palabra era: programacion

# %% [markdown]
# 3. Desarrolla la finalización de la partida, tanto si gana como si pierde.
